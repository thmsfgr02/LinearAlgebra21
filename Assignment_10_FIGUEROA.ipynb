# %% [markdown]
# <a href="https://colab.research.google.com/github/thmsfgr02/LinearAlgebra21/blob/main/Assignment_10_FIGUEROA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ##Linear Combination

# %% [markdown]
# It is said that a linear combination is the combination of linear scaling and addition of a vector its bases/components
#
# We will try to visualize the vectors and their linear combinations by plotting a sample of real number values for the scalars for the vectors. Let's first try the vectors below:

# %% [markdown]
# $$X = \begin{bmatrix} 2\\5 \\\end{bmatrix} , Y = \begin{bmatrix} 7\\9 \\\end{bmatrix} $$

# %%
vectX = np.array([2,5])
vectY = np.array([7,9])

# %% [markdown]
# ###Span of single vectors

# %% [markdown]
# $$X = c\cdot \begin{bmatrix} 2\\5 \\\end{bmatrix} $$

# %%
c = np.arange(-10,10,0.125)

plt.scatter(c*vectX[0],c*vectX[1])

plt.xlim(-10,10)
plt.ylim(-10,10)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %%
c = np.arange(-15,15,0.5)

plt.scatter(c*vectY[0],c*vectY[1])

plt.xlim(-20,20)
plt.ylim(-20,20)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ###Span of linear combination of vectors

# %% [markdown]
# $$S = \begin{Bmatrix} c_1 \cdot\begin{bmatrix} 1\\0 \\\end{bmatrix},
# c_2 \cdot \begin{bmatrix} 1\\-1 \\\end{bmatrix}\end{Bmatrix} $$

# %%
vectA = np.array([1,0])
vectB = np.array([1,-1])

R = np.arange(-10,10,1)
c1, c2 = np.meshgrid(R,R)
vectR = vectA + vectB
spanRx = c1*vectA[0] + c2*vectB[0]
spanRy = c1*vectA[1] + c2*vectB[1]

plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color= 'k')
plt.axvline(x=0, color= 'k')
plt.grid()
plt.show()

# %%
vectP = np.array([2,1])
vectQ = np.array([4,3])

R = np.arange(-10,10,1)

c1, c2 = np.meshgrid(R,R)

vectR = vectP + vectQ
spanRx = c1*vectP[0] + c2*vectQ[0]
spanRy = c1*vectP[1] + c2*vectQ[1]
##plt.scatter(R*vectA[0],R*vectA[1])
##plt.scatter(R*vectB[0],R*vectB[1])
plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# # Activity

# %% [markdown]
# ##**TASK 1**
#
# Try different linear combinations using different scalar values. In your methodology discuss the different functions that you have used, the  linear equation and vector form of the linear combination, and the flowchart for declaring and displaying linear combinations. Please make sure that your flowchart has only few words and not putting the entire code as it is bad practice. In your results, display and discuss the linear combination visualization you made. You should use the cells below for displaying the equation markdows using LaTeX and your code.

# %% [markdown]
# $$
# Space \cdot for \cdot the \cdot general \cdot linear \cdot equation \cdot form
# $$

# %% [markdown]
# $$Space \cdot for \cdot the \cdot vector \cdot form$$

# %% [markdown]
# OUTPUT:

# %% [markdown]
# $$T = \begin{bmatrix} 6\\9 \\\end{bmatrix} , F = \begin{bmatrix} 6\\6 \\\end{bmatrix} $$

# %%
vectT = np.array([6,9])
vectF = np.array([6,6])
vectF
# Out:
# array([6, 6])

# %% [markdown]
# $$M = Q\cdot \begin{bmatrix} 10\\12 \\\end{bmatrix} $$

# %%
Q = np.arange(-16,25,.65)

plt.scatter(C*vectF[0],C*vectF[0])

plt.xlim(-20,20)
plt.ylim(-20,20)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %%
C = np.arange(-12,20,.30)

plt.scatter(C*vectT[0],C*vectT[0])

plt.xlim(-25,25)
plt.ylim(-25,25)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **SPAN of LINEAR COMBINATION VECTORS**

# %% [markdown]
# $$X = \begin{Bmatrix} c_1 \cdot\begin{bmatrix} 10\\6 \\\end{bmatrix},
# c_2 \cdot \begin{bmatrix} 8\\-2 \\\end{bmatrix}\end{Bmatrix} $$

# %%
vectI = np.array([10,6])
vectM = np.array([8,-2])

M = np.arange(-22,14,2)

c1, c2 = np.meshgrid(M,M)

vectX = vectT + vectF
spanMx = c1*vectO[0] + c2*vectP[0]
spanMy = c1*vectO[1] + c2*vectP[1]
##plt.scatter(R*vectA[0],R*vectA[1])
##plt.scatter(R*vectB[0],R*vectB[1])
plt.scatter(spanMx,spanMy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **CONCLUSION**

# %% [markdown]
# Applying the concept of Linear Combination in engineering or in real-life situations:

# %% [markdown]
# > Linear Combination is just an introduction to an exhaustive and yet underrated subtopiv in mathematics over calculus. This in fact brings us comprehensive solutions to assist data efficiency in the field of cryptography, web page ranking, social network analysis, discrete time populetions models and computer graphics.
#
# > We gained new and distinct understanding throughout the previous lab experiments, which are useful to this lab report on linear combination and vector spaces. Because plotting a graph is included in this lab report, it's vital to think about a number of factors when coding. In order for the program to execute as you intended, we must run the preceding line of codes, just like we did in the prior lab trials. as well as avoiding mistakes
